# %% [markdown]
# <h1 align=center><font size = 3>Report of Week 2 Assignment - Battle of Neighbourhoods</font></h1>
# <br>
# <h1 align=center><font size = 5>Similarity of Downtown Toronto and Manhattan, New York neigbourhoods</font></h1>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# #### Problem:
#
# Susan has lived in Downtown Toronto for a long time. She lived in other boroughs in Toronto before but she likes Downtown Toronto the most. She feels safe and happy with the restaurants, shops, recreational and enterainment facilities nearby. She enjoys her life so much there.
#
# Recently Susan has got an offer from a tech copmany in New York, which she has always been dreaming to work in, so she has decided to move to New York to follow her dream. The first thing to do is to find a place to settle down everything. She is looking for an apartment but she has no idea how to start with. She has never been to New York before and she knows New Tork is a big city that she may find difficulty living in such big city. Of course she doesn't know much about how similar New York it is compared to Toronto nor the boroughs/neigbourhoods.
#
# A safer solution is that she can find a place which is similar to Downtown Toronto. Then it may be easier for her to adapt the pace of New York. There is little information online about the comparison of neigbourhoods between New York and Toronto. She needs to make the decision within the next 2 weeks and she doesn't feel she can make it with the current information she've got. She is struggling. Luckily Susan remembers you have told her that you works in Data Science recently and thinks you may be able to help her to find out a solution.
#
# Susan is a good friend of you, therefore you are happy to help. Now you decide to find a way to analyse the data and see if you can find a recommendation for her.

# %% [markdown]
# #### Question:
#
# Can we find neigbourhoods in Manhattan, New York which are similar to Downtown Toronto?

# %% [markdown]
# #### possible interested parties in this project
#
# As this project aims to compare simliarity of the boroughs/neigbourhoods of 2 cities, the following parties may be interested,
#
# - people like Susan who needs to move to a new city
# - property agency for strategic planning and recommendation to increase sales
# - input to city development for the government for better city planning
# - company owners to open branches in areas they desired

# %% [markdown]
# ## 2. Description of Methodology / Data

# %% [markdown]
# #### Analytic Approach
#
# Use K-means clustering to cluster the neighbourhoods

# %% [markdown]
# #### Data Requirements
# - Data of New York and Toronto
#
# - borough and neighbourhood
#
# - location: latitude, longitude
#
# - nearby venues data: venue category, venue count

# %% [markdown]
# #### Data collection and peperation
#
# - list of borough/neighbourhood of New York from NYU
# - list of borough/neighbourhood of Toronto from Wikipedia
# - list of location of the boroughs/neighbourhoods
# - nearby venues of the neighbourhood from Foursquare
#
# Data was collected from different sources, i.e., NYU, Wikipedia, Foursquare. For the nearby venues data, initially crawling from Foursquare API was actively being used during the anaylsis, but the API was not stable and several data sets were stored on the local instead.
# Collecting list of Toronto geolocation was a bit tricky as web crawling was performed. Library *lxml.html* was used to parse the HTML. All `tr` elements were captured and transformed into rows of dataframe. Data cleaning also was required.
#
# Data set information,
# - **Mahanttan, New York**
#     - Borough/Neighbourhood, `manhattan_geo`: 40 rows
#     - Nearby venues, `mahattan_venues`: 3104 rows

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Downtown Toronto**
#     - Borough/Neighbourhood, `toronto_geo`: 19 rows
#     - Nearby venues, `down_toronto_venues`: 1222 rows

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exploratory data analysis
#
# When the frist time the data was prepared, EDA was performed, however, a problem was found out that the data of New York City was extremely large compared to that of Toronto. It slowed down significantly the performance of the computer used for analysis, therefore the original question 'Can we find neigbourhoods in New York which are similar to Toronto?' was refined to 'Can we find neigbourhoods in Manhattan, New York which are similar to Downtown Toronto?', which only Mahattan and Downtown Toronto was considered in this project. It still fits the problem and can find a solution.
#
# To further understand the data, one hot encoding was performed to add the venue category columns and then means of the frequency of all the venue categories were calculated to form data sets `ny_grouped` and `toronto_grouped`, showing the 1st-10th common venues appeared in the neighbourhoods.
#
# After the data collection, data sets were concatenated to form *two_cities* single data set for further analysis.
# - `two_cities_grouped`: combined data set of  means of the frequency
# - `two_cities_common_venues` : this data set would show the 1st-10th common venues appeared in the neighbourhoods
#
# Then NaN (Null) values were found on the concatenated data sets. 0s were filled to avoid errors caused by the NaN values.

# %% [markdown]
# `two_cities_grouped`
# ![image.png](attachment:image.png)

# %% [markdown]
# `two_cities_common_venues`
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Data Modeling

# %% [markdown]
# #### build cluster
#
# Library `sklearn.cluster` was used to build the K-means clustering.
#
# Run k-means to cluster the neighborhood into 8 clusters with a view to check the similarity not more than the count of Toronto neighbourhoods.
#
# k<19

# %% [markdown]
# 3, 8, 19 were used and 8 was found to be easier to draw insights.

# %% [markdown]
# ## 4. Result

# %% [markdown]
# #### count of cluster
# ![image.png](attachment:image.png)

# %% [markdown]
# Based on the data set, we examined the cluster labels = 0,1,3,4 which have >1 count of neighbourhoods.
#
# For other cluster, count = 1 can be omitted as simply there was no clustering on those clusters.

# %% [markdown]
# ## 5. Discussion / Recommendation

# %% [markdown]
# Form cluster labels = 0,1,3, most of the clustered neighbourhoods were in Manhattan, therefore these could be omitted.
#
# When checking the cluster labels = 4, interested insight was found. Out of total 19 rows, 6 rows were Manhattan neighbourhoods while 13 rows were neighbourhoods in Downtown Toronto.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It can be found that one common venue is coffee shop/Cafe. Also restaurants, bars, snack shops are also very common in this cluster. Some recreational and entertainment facilities are shown in the table.

# %% [markdown]
# Recommendation can be made here that the 6 neighbourhoods have some similarities comparing to main neighbouhoods in Downtown Toronto. Here is the list,
# - Chelsea
# - Civic Center
# - Manhattanville
# - Marble Hill
# - Midtown
# - Midtown South

# %% [markdown]
# When choosing k, there were some difference on the venue clusters, one problem may be the venue category was so board that dilute the effect of correlation. It may be worth to group the categories into smaller number of category, also check other features such as crime, air quality, transportation figures, etc. These may contribute more insights on the similarity of the neighbourhoods of various cities/better neighbourhoods to live.
#
# Another suggestion would be, for company owner, relating sales figures of shops in different neighbourhoods to combination of venues so as to classify high sales areas.

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# In this project, it was a very great oppountunity to learn that how a city can have various combination of venues, while at the same time similarity can also be found, for example, there are a lot of restaurants in similar areas. Adapting a new environment may not be so hard, indeed this project can only give little insights to understand the neighbourhoods through clustering. This project would definitely be a good starting point to know into other features that may help to understand our living places.
